# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# CSVファイルを読み込む
df = pd.read_csv("/home/eiji/project/g/preprocessed_data/GarageDoor_LE.csv")
# temp_conditionの文字列をトリム（前後の空白削除）
# df['temp_condition'] = df['temp_condition'].str.strip()
# 一意の値をチェック
# print(df['temp_condition'].unique())
df
# Out:
#         hour  minute  second  door_state_encoded  sphone_signal  label
# 0         20      53      44                   1              1      0
# 1         20      53      49                   0              0      0
# 2         20      53      49                   1              1      0
# 3         20      53      54                   0              0      0
# 4         20      53      54                   1              1      0
# ...      ...     ...     ...                 ...            ...    ...
# 541172    11       3      21                   0              0      0
# 541173    11       3      21                   0              0      0
# 541174    11       3      21                   0              0      0
# 541175    11       3      22                   0              0      0
# 541176    11       3      24                   0              0      0
#
# [541177 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler
# 標準化を適用する列
columns_to_scale = ['hour', 'minute', 'second']

# StandardScalerのインスタンスを作成
scaler = StandardScaler()

# 標準化の適用
df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])

# 結果を表示
df
# Out:
#             hour    minute    second  door_state_encoded  sphone_signal  label
# 0       1.569086  1.699460  0.847250                   1              1      0
# 1       1.569086  1.699460  1.139523                   0              0      0
# 2       1.569086  1.699460  1.139523                   1              1      0
# 3       1.569086  1.699460  1.431795                   0              0      0
# 4       1.569086  1.699460  1.431795                   1              1      0
# ...          ...       ...       ...                 ...            ...    ...
# 541172  0.204461 -1.328975 -0.497203                   0              0      0
# 541173  0.204461 -1.328975 -0.497203                   0              0      0
# 541174  0.204461 -1.328975 -0.497203                   0              0      0
# 541175  0.204461 -1.328975 -0.438749                   0              0      0
# 541176  0.204461 -1.328975 -0.321840                   0              0      0
#
# ...

# %%
df.to_csv('./preprocessed_data/GarageDoor_LE-SS.csv', index=False)
